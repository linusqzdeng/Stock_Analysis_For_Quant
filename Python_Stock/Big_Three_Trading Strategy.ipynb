# %% [markdown]
# # Big Three Trading Strategy

# %% [markdown]
# 20 Period Simple Moving Average
#
# 40 Period Simple Moving Average
#
# 80 Period Simple Moving Average
#
#
# https://tradingstrategyguides.com/big-three-trading-strategy/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'AAPL'
start = '2014-01-01'
end = '2020-12-31'

# Read data 
df = yf.download(symbol, start, end)

# View Columns
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2014-01-02  19.845715  19.893929  19.715000  19.754642  17.568451  234684800
# 2014-01-03  19.745001  19.775000  19.301071  19.320715  17.182550  392467600
# 2014-01-06  19.194643  19.528570  19.057142  19.426071  17.276245  412610800
# 2014-01-07  19.440001  19.498571  19.211430  19.287144  17.152693  317209200
# 2014-01-08  19.243214  19.484285  19.238930  19.409286  17.261324  258529600

# %%
df['SMA_20'] = df['Adj Close'].rolling(20).mean()
df['SMA_40'] = df['Adj Close'].rolling(40).mean()
df['SMA_80'] = df['Adj Close'].rolling(80).mean()

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-12-23  132.160004  132.429993  130.779999  130.960007  130.542862
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  131.549637
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  136.254608
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  134.440399
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  133.294067
#
#                Volume      SMA_20      SMA_40      SMA_80
# Date
# 2020-12-23   88223700  123.710691  119.642488  117.578471
# 2020-12-24   54930100  124.505153  120.164857  117.553813
# 2020-12-28  124486200  125.506952  120.702354  117.622548
# 2020-12-29  121047300  126.295432  121.355205  117.799460
# 2020-12-30   96452100  126.843679  121.981637  117.961047

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.plot(df.index, df['Adj Close'], label='Price')
ax.plot(df.index, df['SMA_20'], label='20-days SMA')
ax.plot(df.index, df['SMA_40'], label='40-days SMA')
ax.plot(df.index, df['SMA_80'], label='80-days SMA')

ax.legend(loc='best')
ax.set_ylabel('Price')
ax.set_title('Big Three Trading Strategy')
ax.grid(True)
plt.show()

# %% [markdown]
# ## Closer View
#
# plot different dates

# %%
new_dates = df['2019-01-01':'2020-12-31']
new_dates.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2019-01-02  38.722500  39.712502  38.557499  39.480000  38.439735  148158800
# 2019-01-03  35.994999  36.430000  35.500000  35.547501  34.610851  365248800
# 2019-01-04  36.132500  37.137501  35.950001  37.064999  36.088364  234428400
# 2019-01-07  37.174999  37.207500  36.474998  36.982498  36.008041  219111200
# 2019-01-08  37.389999  37.955002  37.130001  37.687500  36.694466  164101200
#
#                SMA_20     SMA_40     SMA_80
# Date
# 2019-01-02  39.907269  43.022278  48.323028
# 2019-01-03  39.388435  42.629358  48.084665
# 2019-01-04  39.042424  42.309093  47.873776
# 2019-01-07  38.716372  41.973600  47.645145
# 2019-01-08  38.500465  41.617792  47.433524

# %%
# %matplotlib inline
plt.style.use('fivethirtyeight')

plt.figure(figsize=(16,10))
plt.plot(new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label='20-days SMA')
plt.plot(new_dates['SMA_40'], label='40-days SMA')
plt.plot(new_dates['SMA_80'], label='80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')

plt.show()

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index, y=new_dates['Adj Close'], label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA')
plt.plot(new_dates['SMA_40'], label = '40-days SMA')
plt.plot(new_dates['SMA_80'], label = '80-days SMA')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Dates')
plt.title('Big Three Trading Strategy')

plt.show()

# %%
plt.figure(figsize=(16,10))
plt.plot_date(x=new_dates.index ,y=new_dates['Adj Close'], fmt='r-', label='Price')
plt.plot(new_dates['SMA_20'], label = '20-days SMA', color='b')
plt.plot(new_dates['SMA_40'], label = '40-days SMA', color='y')
plt.plot(new_dates['SMA_80'], label = '80-days SMA', color='green')
plt.legend(loc='best')
plt.grid(True)
plt.ylabel('Price')
plt.xlabel('Date')
plt.title('Big Three Trading Strategy')

plt.show()
